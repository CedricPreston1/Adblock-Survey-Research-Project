# %% [markdown]
# Doing this for adblockers.
#
# Mostly renaming to simplify interpreting results.
#
# Meanings are from the kaggle site.

# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_csv(pwd + '/Adblock_Survey.csv')
dataset
# Out:
#          Sex  Age  Current_users_of_ad_blockers  Past_users_of_ad_blockers  \
# 0     female   30                             0                          0
# 1       male   35                             1                          0
# 2       male   41                             0                          1
# 3       male   38                             0                          1
# 4     female   42                             0                          0
# ...      ...  ...                           ...                        ...
# 1506  female   21                             0                          0
# 1507  female   52                             1                          0
# 1508    male   37                             0                          0
# 1509    male   50                             0                          0
# 1510  female   20                             0                          0
#
# ...

# %%
df = dataset.copy() 
df #Making a copy to avoid mistakes
# Out:
#          Sex  Age  Current_users_of_ad_blockers  Past_users_of_ad_blockers  \
# 0     female   30                             0                          0
# 1       male   35                             1                          0
# 2       male   41                             0                          1
# 3       male   38                             0                          1
# 4     female   42                             0                          0
# ...      ...  ...                           ...                        ...
# 1506  female   21                             0                          0
# 1507  female   52                             1                          0
# 1508    male   37                             0                          0
# 1509    male   50                             0                          0
# 1510  female   20                             0                          0
#
# ...

# %% [markdown]
# Renaming Columns for better accuracy

# %%
df.columns
# Out:
# Index(['Sex', 'Age', 'Current_users_of_ad_blockers',
#        'Past_users_of_ad_blockers', 'kab_1', 'kab_2', 'kab_3', 'kab_4',
#        'aoa_1', 'aoa_2', 'aoa_3', 'aoa_4', 'poa_1', 'poa_2', 'poa_3', 'poa_4',
#        'coa_1', 'coa_2', 'coa_3', 'coa_4', 'eoa_1', 'eoa_2', 'eoa_3', 'eoa_4',
#        'ioa_1', 'ioa_2', 'ioa_3', 'ioa_4', 'oac_1', 'oac_2', 'oac_3', 'oac_4'],
#       dtype='object')

# %%
df = df.rename(columns= {'kab_1' : 'I have knowledge about the tools that block Internet advertising such as AdBlock.',
'kab_2' : 'I am aware that these tools (ad blockers) are easy to install on a computer.',
'kab_3' : 'I know that ad blockers reduce risk of viruses and malicious software.',
'kab_4' : 'I know that these blockers filter out advertisements that might interest me.',
'aoa_1' : 'I think Internet advertisements are worth it.',
'aoa_2' : 'Generally, I consider Internet advertising to be a good thing.',
'aoa_3' : 'My general opinion about Internet advertising is highly favorable.',
'aoa_4' : 'I appreciate seeing advertising messages on the Internet.',
'poa_1' : 'Internet advertising is very entertaining.',
'poa_2' : 'Sometimes I take pleasure in thinking about what I saw or heard on online ads.',
'poa_3' : 'Viewing online advertisements is a pleasant experience for me.',
'poa_4' : 'Sometimes online advertising is even more enjoyable than other Internet content.',
'coa_1' : 'Consumers may obtain reliable information through Internet advertising.',
'coa_2' : 'Most Internet advertisements are trustworthy.',
'coa_3' : 'Online advertisements reliably inform about the quality of products.',
'coa_4' : 'Internet advertisements accurately reflect what products are like.',
'eoa_1' : 'Internet advertising contributes to society’s economic development.',
'eoa_2' : 'Internet advertising helps raise our standard of living.',
'eoa_3' : 'Online advertisements promote competition, which benefits consumers.',
'eoa_4' : 'Online advertisements are necessary to support websites.',
'ioa_1' : 'Online advertising gets in the way of my Internet searches.',
'ioa_2' : 'Online advertising disrupts my activity on the Internet.',
'ioa_3' : 'Online advertising distracts me from my objectives while on the Internet.',
'ioa_4' : 'Internet advertisements intrude on the content I am accessing.',
'oac_1' : 'There are too many advertisements on the Internet.',
'oac_2' : 'Internet advertisements are very repetitive.',
'oac_3' : 'Web sites are full of advertising messages.',
'oac_4' : 'We Internet users are inundated with so much online advertising.',}) #Renaming straight from kaggle source.

df
# Out:
#          Sex  Age  Current_users_of_ad_blockers  Past_users_of_ad_blockers  \
# 0     female   30                             0                          0
# 1       male   35                             1                          0
# 2       male   41                             0                          1
# 3       male   38                             0                          1
# 4     female   42                             0                          0
# ...      ...  ...                           ...                        ...
# 1506  female   21                             0                          0
# 1507  female   52                             1                          0
# 1508    male   37                             0                          0
# 1509    male   50                             0                          0
# 1510  female   20                             0                          0
#
# ...

# %%
df.columns
# Out:
# Index(['Sex', 'Age', 'Current_users_of_ad_blockers',
#        'Past_users_of_ad_blockers',
#        'I have knowledge about the tools that block Internet advertising such as AdBlock.',
#        'I am aware that these tools (ad blockers) are easy to install on a computer.',
#        'I know that ad blockers reduce risk of viruses and malicious software.',
#        'I know that these blockers filter out advertisements that might interest me.',
#        'I think Internet advertisements are worth it.',
#        'Generally, I consider Internet advertising to be a good thing.',
#        'My general opinion about Internet advertising is highly favorable.',
#        'I appreciate seeing advertising messages on the Internet.',
#        'Internet advertising is very entertaining.',
#        'Sometimes I take pleasure in thinking about what I saw or heard on online ads.',
#        'Viewing online advertisements is a pleasant experience for me.',
# ...

# %%
df = df.rename(columns= {'Current_users_of_ad_blockers' : 'Current users of ad blockers', 'Past_users_of_ad_blockers' : 'Past users of ad blockers'})
df #renaming the last two columns
# Out:
#          Sex  Age  Current users of ad blockers  Past users of ad blockers  \
# 0     female   30                             0                          0
# 1       male   35                             1                          0
# 2       male   41                             0                          1
# 3       male   38                             0                          1
# 4     female   42                             0                          0
# ...      ...  ...                           ...                        ...
# 1506  female   21                             0                          0
# 1507  female   52                             1                          0
# 1508    male   37                             0                          0
# 1509    male   50                             0                          0
# 1510  female   20                             0                          0
#
# ...

# %% [markdown]
# Fixing the answers of "Current users of ad blockers" and "Past users of ad blockers"

# %%
df2 = df.copy()

# %%
df2
# Out:
#          Sex  Age  Current users of ad blockers  Past users of ad blockers  \
# 0     female   30                             0                          0
# 1       male   35                             1                          0
# 2       male   41                             0                          1
# 3       male   38                             0                          1
# 4     female   42                             0                          0
# ...      ...  ...                           ...                        ...
# 1506  female   21                             0                          0
# 1507  female   52                             1                          0
# 1508    male   37                             0                          0
# 1509    male   50                             0                          0
# 1510  female   20                             0                          0
#
# ...

# %%
df2[['Current users of ad blockers', 'Past users of ad blockers']] = df2[['Current users of ad blockers', 'Past users of ad blockers']].replace({1 : 'Yes', 0 : 'Other'})
df2 #this is what I want to rename it to for these two columns, "Other" because the answer could have been anything else that wasn't "No"
# Out:
#          Sex  Age Current users of ad blockers Past users of ad blockers  \
# 0     female   30                        Other                     Other
# 1       male   35                          Yes                     Other
# 2       male   41                        Other                       Yes
# 3       male   38                        Other                       Yes
# 4     female   42                        Other                     Other
# ...      ...  ...                          ...                       ...
# 1506  female   21                        Other                     Other
# 1507  female   52                          Yes                     Other
# 1508    male   37                        Other                     Other
# 1509    male   50                        Other                     Other
# 1510  female   20                        Other                     Other
#
#       I have knowledge about the tools that block Internet advertising such as AdBlock.  \
# ...

# %% [markdown]
# Now I will need to rename the scale answers from Numerical to worded answers. This is what it looks like
#
# 3 Completely Agree
#
# 2 Agree
#
# 1 Somewhat Agree
#
# 0 Neutral
#
# -1 Somewhat Disagree
#
# -2 Disagree
#
# -3 Completely Disagree
#
# The source from kaggle only refers 3 and -3 as "Completely Agree' and "Completely Disagree" Respectuflly
#
# So i'm just going to assum -2 and 2 are "Highly disagree" and "Highly agree" and so on.

# %%
df3 = df2.copy()
df3 #Another copy just in case
# Out:
#          Sex  Age Current users of ad blockers Past users of ad blockers  \
# 0     female   30                        Other                     Other
# 1       male   35                          Yes                     Other
# 2       male   41                        Other                       Yes
# 3       male   38                        Other                       Yes
# 4     female   42                        Other                     Other
# ...      ...  ...                          ...                       ...
# 1506  female   21                        Other                     Other
# 1507  female   52                          Yes                     Other
# 1508    male   37                        Other                     Other
# 1509    male   50                        Other                     Other
# 1510  female   20                        Other                     Other
#
#       I have knowledge about the tools that block Internet advertising such as AdBlock.  \
# ...

# %%
replace_map = {-3 : 'Completely Disagree',
               -2 : 'Disagree',
               -1 : 'Somewhat Disagree',
               0 : 'Neutral',
               1 : 'Somewhat Agree',
               2 : 'Agree',
               3 : 'Completely Agree'}

# %%
df3 = df3.replace(replace_map)
df3
# Out:
#          Sex  Age Current users of ad blockers Past users of ad blockers  \
# 0     female   30                        Other                     Other
# 1       male   35                          Yes                     Other
# 2       male   41                        Other                       Yes
# 3       male   38                        Other                       Yes
# 4     female   42                        Other                     Other
# ...      ...  ...                          ...                       ...
# 1506  female   21                        Other                     Other
# 1507  female   52                          Yes                     Other
# 1508    male   37                        Other                     Other
# 1509    male   50                        Other                     Other
# 1510  female   20                        Other                     Other
#
#      I have knowledge about the tools that block Internet advertising such as AdBlock.  \
# ...

# %% [markdown]
# Looking at some of the data

# %%
import matplotlib.pyplot as plt

# %%
Current_users = df3['Current users of ad blockers'].value_counts()
Past_users = df3['Past users of ad blockers'].value_counts() #setup

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,8), sharey=True)

axes[0].bar(Current_users.index, Current_users.values, color='deepskyblue')
axes[0].set_title('Current users of Ad Blockers')
axes[0].set_xlabel('Response')
axes[0].set_ylabel('Count')

axes[1].bar(Past_users.index, Past_users.values, color= 'limegreen')
axes[1].set_title('Past users of Ad Blockers')
axes[1].set_xlabel('Response')

plt.tight_layout()
plt.show() #For the overall

# %%
#Here I'm lowering the age range down to 35 and under and filtering the sex to male to see if there's a factor here.
filtered_df = df3[(df3['Age'] <= 35) & (df3['Sex'].str.lower()=='male')]
grouped_current = filtered_df.groupby('Sex')['Current users of ad blockers'].value_counts().unstack().fillna(0)
grouped_past = filtered_df.groupby('Sex')['Past users of ad blockers'].value_counts().unstack().fillna(0)

fig, axes = plt.subplots(1, 2, figsize=(12,8), sharey=True)

grouped_current.plot(kind='bar', ax=axes[0], color=['crimson', 'deepskyblue'])
axes[0].set_title('Current users of Ad Blockers')
axes[0].set_xlabel('Response')
axes[0].set_ylabel('Count')

grouped_past.plot(kind='bar', ax=axes[1], color=['crimson', 'limegreen'])
axes[1].set_title('Past users of Ad Blockers')
axes[1].set_xlabel('Response')

plt.tight_layout()
plt.show()

# %%
#And THERE IS. It looks like there's a difference if you filter down the age and sex. But lets check the other gender first just to be sure
#Same age range different gender
#For reasons why, I'm going to copy and paste the string so that an actual change can be seen, though in practice it'll probably not be necessary.
filtered_df = df3[(df3['Age'] <= 35) & (df3['Sex'].str.lower()=='female')]
grouped_current = filtered_df.groupby('Sex')['Current users of ad blockers'].value_counts().unstack().fillna(0)
grouped_past = filtered_df.groupby('Sex')['Past users of ad blockers'].value_counts().unstack().fillna(0)

fig, axes = plt.subplots(1, 2, figsize=(12,8), sharey=True)

grouped_current.plot(kind='bar', ax=axes[0], color=['crimson', 'deepskyblue'])
axes[0].set_title('Current users of Ad Blockers')
axes[0].set_xlabel('Response')
axes[0].set_ylabel('Count')

grouped_past.plot(kind='bar', ax=axes[1], color=['crimson', 'limegreen'])
axes[1].set_title('Past users of Ad Blockers')
axes[1].set_xlabel('Response')

plt.tight_layout()
plt.show()

# %%
#Now lets compare
filtered_df = df3[(df3['Age'] <= 35)]
grouped_current = filtered_df.groupby('Sex')['Current users of ad blockers'].value_counts().unstack().fillna(0)
grouped_past = filtered_df.groupby('Sex')['Past users of ad blockers'].value_counts().unstack().fillna(0)

fig, axes = plt.subplots(1, 2, figsize=(12, 8), sharey=True)

grouped_current.plot(kind='bar', ax=axes[0], color=['crimson', 'deepskyblue'])
axes[0].set_title('Current users of Ad Blockers')
axes[0].set_xlabel('Response')
axes[0].set_ylabel('Count')

grouped_past.plot(kind='bar', ax=axes[1], color=['crimson', 'limegreen'])
axes[1].set_title('Past users of Ad Blockers')
axes[1].set_xlabel('Response')

plt.tight_layout()
plt.show()

# %%
#Looking at just the same age range
filtered_df = df3[(df3['Age'] <= 35)]
grouped_current = filtered_df['Current users of ad blockers'].value_counts()
grouped_past = filtered_df['Past users of ad blockers'].value_counts()

fig, axes = plt.subplots(1, 2, figsize=(12,8), sharey=True)

grouped_current.plot(kind='bar', ax=axes[0], color=['crimson', 'deepskyblue'])
axes[0].set_title('Current users of Ad Blockers')
axes[0].set_xlabel('Response')
axes[0].set_ylabel('Count')

grouped_past.plot(kind='bar', ax=axes[1], color=['crimson', 'limegreen'])
axes[1].set_title('Past users of Ad Blockers')
axes[1].set_xlabel('Response')

plt.tight_layout()
plt.show()

# %%
#Looking at a different age range
filtered_df = df3[(df3['Age'] >= 35)]
grouped_current = filtered_df['Current users of ad blockers'].value_counts()
grouped_past = filtered_df['Past users of ad blockers'].value_counts()

fig, axes = plt.subplots(1, 2, figsize=(12, 8), sharey=True)

grouped_current.plot(kind='bar', ax=axes[0], color=['crimson', 'deepskyblue'])
axes[0].set_title('Current users of Ad Blockers')
axes[0].set_xlabel('Response')
axes[0].set_ylabel('Count')

grouped_past.plot(kind='bar', ax=axes[1], color=['crimson', 'limegreen'])
axes[1].set_title('Past users of Ad Blockers')
axes[1].set_xlabel('Response')

plt.tight_layout()
plt.show()

# %%
#These are JUST to make sure on whether or not age determines whether or not you'll use an ad blocker
filtered_df = df3[(df3['Age'] >= 35) & (df3['Sex'].str.lower()=='male')]
grouped_current = filtered_df.groupby('Sex')['Current users of ad blockers'].value_counts().unstack().fillna(0)
grouped_past = filtered_df.groupby('Sex')['Past users of ad blockers'].value_counts().unstack().fillna(0)

fig, axes = plt.subplots(1, 2, figsize=(12, 8), sharey=True)

grouped_current.plot(kind='bar', ax=axes[0], color=['crimson', 'deepskyblue'])
axes[0].set_title('Current users of Ad Blockers')
axes[0].set_xlabel('Response')
axes[0].set_ylabel('Count')

grouped_past.plot(kind='bar', ax=axes[1], color=['crimson', 'limegreen'])
axes[1].set_title('Past users of Ad Blockers')
axes[1].set_xlabel('Response')

plt.tight_layout()
plt.show()

# %%
filtered_df = df3[(df3['Age'] >= 35) & (df3['Sex'].str.lower()=='female')]
grouped_current = filtered_df.groupby('Sex')['Current users of ad blockers'].value_counts().unstack().fillna(0)
grouped_past = filtered_df.groupby('Sex')['Past users of ad blockers'].value_counts().unstack().fillna(0)

fig, axes = plt.subplots(1, 2, figsize=(12, 8), sharey=True)

grouped_current.plot(kind='bar', ax=axes[0], color=['crimson', 'deepskyblue'])
axes[0].set_title('Current users of Ad Blockers')
axes[0].set_xlabel('Response')
axes[0].set_ylabel('Count')

grouped_past.plot(kind='bar', ax=axes[1], color=['crimson', 'limegreen'])
axes[1].set_title('Past users of Ad Blockers')
axes[1].set_xlabel('Response')

plt.tight_layout()
plt.show()

# %% [markdown]
# Explaining why this is important to know

# %%
#It's probably better to put this set through a Bi Tool to make things easier, but I wanted to at least show some of the data here
#Younger males may be more likely to admit that they have an ad blocker
#More research may be needed on that statement but I think I'm more than satisfied on this answer for now

# %%
df3.to_csv('Adblock_Survey_Clean.csv', index=False)
